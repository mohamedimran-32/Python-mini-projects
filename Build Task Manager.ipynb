# %%
import psutil

#Get a list of all running processes
running_processes = psutil.process_iter(attrs = ['pid','name','status'])

#Iterate through the list and print process information
for process in running_processes:
    process_info = process.info
    pid = process_info['pid']
    name = process_info['name']
    status = process_info['status']
    print(f"PID: {pid}, NAME: {name}, STATUS: {status}")
# Out:
# PID: 0, NAME: System Idle Process, STATUS: running
# PID: 4, NAME: System, STATUS: running
# PID: 140, NAME: , STATUS: stopped
# PID: 180, NAME: Registry, STATUS: running
# PID: 420, NAME: wininit.exe, STATUS: running
# PID: 632, NAME: svchost.exe, STATUS: running
# PID: 652, NAME: smss.exe, STATUS: running
# PID: 784, NAME: svchost.exe, STATUS: running
# PID: 944, NAME: csrss.exe, STATUS: running
# PID: 1020, NAME: svchost.exe, STATUS: running
# PID: 1072, NAME: services.exe, STATUS: running
# PID: 1112, NAME: LsaIso.exe, STATUS: running
# PID: 1120, NAME: lsass.exe, STATUS: running
# PID: 1136, NAME: IntelCpHDCPSvc.exe, STATUS: running
# PID: 1184, NAME: svchost.exe, STATUS: running
# PID: 1260, NAME: svchost.exe, STATUS: running
# PID: 1292, NAME: WUDFHost.exe, STATUS: running
# PID: 1300, NAME: fontdrvhost.exe, STATUS: running
# PID: 1432, NAME: svchost.exe, STATUS: running
# PID: 1488, NAME: svchost.exe, STATUS: running
# PID: 1616, NAME: WUDFHost.exe, STATUS: running
# PID: 1644, NAME: audiodg.exe, STATUS: running
# PID: 1704, NAME: svchost.exe, STATUS: running
# PID: 1712, NAME: svchost.exe, STATUS: running
# PID: 1740, NAME: svchost.exe, STATUS: running
# PID: 1752, NAME: svchost.exe, STATUS: running
# PID: 1792, NAME: svchost.exe, STATUS: running
# PID: 1800, NAME: RuntimeBroker.exe, STATUS: running
# PID: 1924, NAME: svchost.exe, STATUS: running
# PID: 1932, NAME: svchost.exe, STATUS: running
# PID: 1944, NAME: svchost.exe, STATUS: running
# PID: 2028, NAME: svchost.exe, STATUS: running
# PID: 2104, NAME: svchost.exe, STATUS: running
# PID: 2164, NAME: svchost.exe, STATUS: running
# PID: 2200, NAME: svchost.exe, STATUS: running
# PID: 2332, NAME: IntelCpHeciSvc.exe, STATUS: running
# PID: 2360, NAME: svchost.exe, STATUS: running
# PID: 2388, NAME: svchost.exe, STATUS: running
# PID: 2452, NAME: msedgewebview2.exe, STATUS: running
# PID: 2456, NAME: svchost.exe, STATUS: running
# PID: 2620, NAME: svchost.exe, STATUS: running
# PID: 2764, NAME: OpenConsole.exe, STATUS: running
# PID: 2772, NAME: svchost.exe, STATUS: running
# PID: 2868, NAME: UshUpgradeService.exe, STATUS: running
# PID: 2876, NAME: msedgewebview2.exe, STATUS: running
# PID: 2920, NAME: svchost.exe, STATUS: running
# PID: 2968, NAME: svchost.exe, STATUS: running
# PID: 2984, NAME: svchost.exe, STATUS: running
# PID: 3064, NAME: AggregatorHost.exe, STATUS: running
# PID: 3192, NAME: MemCompression, STATUS: running
# PID: 3252, NAME: svchost.exe, STATUS: running
# PID: 3292, NAME: svchost.exe, STATUS: running
# PID: 3360, NAME: igfxCUIService.exe, STATUS: running
# PID: 3380, NAME: svchost.exe, STATUS: running
# PID: 3416, NAME: chrome.exe, STATUS: running
# PID: 3420, NAME: svchost.exe, STATUS: running
# PID: 3428, NAME: svchost.exe, STATUS: running
# PID: 3468, NAME: svchost.exe, STATUS: running
# PID: 3560, NAME: svchost.exe, STATUS: running
# PID: 3592, NAME: spoolsv.exe, STATUS: running
# PID: 3600, NAME: RtkAudioService64.exe, STATUS: running
# PID: 3608, NAME: svchost.exe, STATUS: running
# PID: 3696, NAME: svchost.exe, STATUS: running
# PID: 3700, NAME: svchost.exe, STATUS: running
# PID: 3764, NAME: chrome.exe, STATUS: running
# PID: 3784, NAME: svchost.exe, STATUS: running
# PID: 3836, NAME: svchost.exe, STATUS: running
# PID: 3916, NAME: svchost.exe, STATUS: running
# PID: 3940, NAME: HostStorageService.exe, STATUS: running
# PID: 3976, NAME: python.exe, STATUS: running
# PID: 4000, NAME: csrss.exe, STATUS: running
# PID: 4040, NAME: msedgewebview2.exe, STATUS: running
# PID: 4044, NAME: svchost.exe, STATUS: running
# PID: 4080, NAME: svchost.exe, STATUS: running
# PID: 4104, NAME: HostControlService.exe, STATUS: running
# PID: 4124, NAME: msedge.exe, STATUS: running
# PID: 4184, NAME: svchost.exe, STATUS: running
# PID: 4248, NAME: OpenConsole.exe, STATUS: running
# PID: 4304, NAME: svchost.exe, STATUS: running
# PID: 4428, NAME: chrome.exe, STATUS: running
# PID: 4440, NAME: svchost.exe, STATUS: running
# PID: 4448, NAME: DellFFDPWmiService.exe, STATUS: running
# PID: 4456, NAME: HidMonitorSvc.exe, STATUS: running
# PID: 4464, NAME: svchost.exe, STATUS: running
# PID: 4476, NAME: svchost.exe, STATUS: running
# PID: 4488, NAME: svchost.exe, STATUS: running
# PID: 4496, NAME: svchost.exe, STATUS: running
# PID: 4548, NAME: OneApp.IGCC.WinService.exe, STATUS: running
# PID: 4560, NAME: OfficeClickToRun.exe, STATUS: running
# PID: 4572, NAME: svchost.exe, STATUS: running
# PID: 4596, NAME: LMS.exe, STATUS: running
# PID: 4628, NAME: MpDefenderCoreService.exe, STATUS: running
# PID: 4672, NAME: mysqld.exe, STATUS: running
# PID: 4712, NAME: SearchIndexer.exe, STATUS: running
# PID: 4752, NAME: esif_uf.exe, STATUS: running
# PID: 4768, NAME: svchost.exe, STATUS: running
# PID: 4828, NAME: WidgetService.exe, STATUS: running
# PID: 4848, NAME: svchost.exe, STATUS: running
# PID: 4856, NAME: RstMwService.exe, STATUS: running
# PID: 4872, NAME: svchost.exe, STATUS: running
# PID: 4904, NAME: WavesSysSvc64.exe, STATUS: running
# PID: 4920, NAME: svchost.exe, STATUS: running
# PID: 4928, NAME: MsMpEng.exe, STATUS: running
# PID: 4956, NAME: WMIRegistrationService.exe, STATUS: running
# PID: 5000, NAME: svchost.exe, STATUS: running
# PID: 5036, NAME: RAVBg64.exe, STATUS: running
# PID: 5044, NAME: python.exe, STATUS: running
# PID: 5132, NAME: svchost.exe, STATUS: running
# PID: 5156, NAME: jhi_service.exe, STATUS: running
# PID: 5200, NAME: WindowsTerminal.exe, STATUS: running
# PID: 5292, NAME: FileSyncHelper.exe, STATUS: running
# PID: 5368, NAME: wlanext.exe, STATUS: running
# PID: 5372, NAME: svchost.exe, STATUS: running
# PID: 5428, NAME: brave.exe, STATUS: running
# PID: 5476, NAME: ShellExperienceHost.exe, STATUS: stopped
# PID: 5572, NAME: mysqld.exe, STATUS: running
# PID: 5776, NAME: conhost.exe, STATUS: running
# PID: 5780, NAME: svchost.exe, STATUS: running
# PID: 6312, NAME: msedgewebview2.exe, STATUS: running
# PID: 6336, NAME: WhatsApp.exe, STATUS: stopped
# PID: 6472, NAME: svchost.exe, STATUS: running
# PID: 6516, NAME: WmiPrvSE.exe, STATUS: running
# PID: 6648, NAME: chrome.exe, STATUS: running
# PID: 6788, NAME: svchost.exe, STATUS: running
# PID: 6932, NAME: svchost.exe, STATUS: running
# PID: 6940, NAME: svchost.exe, STATUS: running
# PID: 6972, NAME: chrome.exe, STATUS: running
# PID: 7024, NAME: gamingservices.exe, STATUS: running
# PID: 7032, NAME: gamingservicesnet.exe, STATUS: running
# PID: 7064, NAME: brave.exe, STATUS: running
# PID: 7116, NAME: svchost.exe, STATUS: running
# PID: 7244, NAME: svchost.exe, STATUS: running
# PID: 7268, NAME: msedgewebview2.exe, STATUS: running
# PID: 7472, NAME: msedgewebview2.exe, STATUS: running
# PID: 7532, NAME: svchost.exe, STATUS: running
# PID: 7764, NAME: svchost.exe, STATUS: running
# PID: 7788, NAME: ApMsgFwd.exe, STATUS: running
# PID: 7824, NAME: NisSrv.exe, STATUS: running
# PID: 7924, NAME: msedge.exe, STATUS: running
# PID: 7968, NAME: svchost.exe, STATUS: running
# PID: 8132, NAME: hidfind.exe, STATUS: running
# PID: 8284, NAME: svchost.exe, STATUS: running
# PID: 8348, NAME: SecurityHealthService.exe, STATUS: running
# PID: 8364, NAME: svchost.exe, STATUS: running
# PID: 8448, NAME: svchost.exe, STATUS: running
# PID: 8496, NAME: chrome.exe, STATUS: running
# PID: 8500, NAME: ms-teams.exe, STATUS: running
# PID: 8540, NAME: chrome.exe, STATUS: running
# PID: 8556, NAME: svchost.exe, STATUS: running
# PID: 8704, NAME: msedgewebview2.exe, STATUS: running
# PID: 8820, NAME: PhoneExperienceHost.exe, STATUS: running
# PID: 8896, NAME: svchost.exe, STATUS: running
# PID: 8904, NAME: svchost.exe, STATUS: running
# PID: 9116, NAME: msedgewebview2.exe, STATUS: running
# PID: 9352, NAME: RuntimeBroker.exe, STATUS: running
# PID: 9408, NAME: msedgewebview2.exe, STATUS: running
# PID: 9524, NAME: chrome.exe, STATUS: running
# PID: 9556, NAME: BraveCrashHandler.exe, STATUS: running
# PID: 9728, NAME: BraveCrashHandler64.exe, STATUS: running
# PID: 9792, NAME: AppActions.exe, STATUS: running
# PID: 10044, NAME: CrossDeviceService.exe, STATUS: running
# PID: 10232, NAME: msedgewebview2.exe, STATUS: running
# PID: 10348, NAME: msedge.exe, STATUS: running
# PID: 10540, NAME: chrome.exe, STATUS: running
# PID: 10560, NAME: CrossDeviceResume.exe, STATUS: running
# PID: 10592, NAME: cmd.exe, STATUS: running
# PID: 10616, NAME: msedge.exe, STATUS: running
# PID: 10692, NAME: svchost.exe, STATUS: running
# PID: 10960, NAME: sihost.exe, STATUS: running
# PID: 10980, NAME: conhost.exe, STATUS: running
# PID: 11004, NAME: RuntimeBroker.exe, STATUS: running
# PID: 11044, NAME: svchost.exe, STATUS: running
# PID: 11064, NAME: svchost.exe, STATUS: running
# PID: 11148, NAME: svchost.exe, STATUS: running
# PID: 11168, NAME: svchost.exe, STATUS: running
# PID: 11280, NAME: msedgewebview2.exe, STATUS: running
# PID: 11300, NAME: chrome.exe, STATUS: running
# PID: 11340, NAME: igfxEM.exe, STATUS: running
# PID: 11348, NAME: svchost.exe, STATUS: running
# PID: 11404, NAME: msedgewebview2.exe, STATUS: running
# PID: 11740, NAME: RAVBg64.exe, STATUS: running
# PID: 11764, NAME: msedgewebview2.exe, STATUS: running
# PID: 11772, NAME: Apoint.exe, STATUS: running
# PID: 11808, NAME: msedgewebview2.exe, STATUS: running
# PID: 11972, NAME: explorer.exe, STATUS: running
# PID: 11992, NAME: unsecapp.exe, STATUS: running
# PID: 12024, NAME: svchost.exe, STATUS: running
# PID: 12028, NAME: ApntEx.exe, STATUS: running
# PID: 12208, NAME: chrome.exe, STATUS: running
# PID: 12316, NAME: ApRemote.exe, STATUS: running
# PID: 12404, NAME: TextInputHost.exe, STATUS: running
# PID: 12544, NAME: ApplicationFrameHost.exe, STATUS: running
# PID: 12572, NAME: taskhostw.exe, STATUS: running
# PID: 12616, NAME: python.exe, STATUS: running
# PID: 12660, NAME: chrome.exe, STATUS: running
# PID: 12752, NAME: ctfmon.exe, STATUS: running
# PID: 12756, NAME: svchost.exe, STATUS: running
# PID: 12776, NAME: msedgewebview2.exe, STATUS: running
# PID: 12900, NAME: RAVBg64.exe, STATUS: running
# PID: 12908, NAME: msedgewebview2.exe, STATUS: running
# PID: 12948, NAME: StartMenuExperienceHost.exe, STATUS: running
# PID: 13084, NAME: conhost.exe, STATUS: running
# PID: 13124, NAME: svchost.exe, STATUS: running
# PID: 13152, NAME: svchost.exe, STATUS: running
# PID: 13164, NAME: msedgewebview2.exe, STATUS: running
# PID: 13224, NAME: svchost.exe, STATUS: running
# PID: 13272, NAME: SearchHost.exe, STATUS: running
# PID: 13276, NAME: python.exe, STATUS: running
# PID: 13320, NAME: winlogon.exe, STATUS: running
# PID: 13432, NAME: fontdrvhost.exe, STATUS: running
# PID: 13476, NAME: svchost.exe, STATUS: running
# PID: 13580, NAME: RuntimeBroker.exe, STATUS: running
# PID: 13628, NAME: Widgets.exe, STATUS: running
# PID: 13692, NAME: OneDrive.exe, STATUS: running
# PID: 13756, NAME: dwm.exe, STATUS: running
# PID: 13876, NAME: msedgewebview2.exe, STATUS: running
# PID: 14440, NAME: UserOOBEBroker.exe, STATUS: running
# PID: 14460, NAME: RuntimeBroker.exe, STATUS: running
# PID: 14468, NAME: MoNotificationUx.exe, STATUS: running
# PID: 14612, NAME: SearchProtocolHost.exe, STATUS: running
# PID: 14668, NAME: ms-teams.exe, STATUS: running
# PID: 14704, NAME: WavesSvc64.exe, STATUS: running
# PID: 14768, NAME: conhost.exe, STATUS: running
# PID: 14808, NAME: brave.exe, STATUS: running
# PID: 14852, NAME: brave.exe, STATUS: running
# PID: 15060, NAME: brave.exe, STATUS: running
# PID: 15072, NAME: brave.exe, STATUS: running
# PID: 15136, NAME: brave.exe, STATUS: running
# PID: 15336, NAME: brave.exe, STATUS: running
# PID: 15396, NAME: SystemSettings.exe, STATUS: stopped
# PID: 15640, NAME: msedge.exe, STATUS: running
# PID: 15800, NAME: python.exe, STATUS: running
# PID: 15892, NAME: RtkNGUI64.exe, STATUS: running
# PID: 16020, NAME: brave.exe, STATUS: running
# PID: 16172, NAME: msedgewebview2.exe, STATUS: running
# PID: 16184, NAME: ShellHost.exe, STATUS: running
# PID: 16276, NAME: chrome.exe, STATUS: running
